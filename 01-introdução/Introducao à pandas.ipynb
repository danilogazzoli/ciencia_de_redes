# %% [markdown]
# # Introdução expressa de Pandas

# %% [markdown]
# ### Dataset: negócios disponíveis no Yelp para a cidade de Toronto -- 2018.
# ### Este documento visa ilustrar recursos importantes de Pandas.

# %%
#Análise e manipulação de dados 
import pandas as pd

# %% [markdown]
# ### Carregando os dados

# %%
# Caso esteja acessando na sua máquina
dfBusiToronto = pd.read_csv('businessToronto.csv')


# Uso no google colab (usar essas linhas - reconhecer o seu drive e substituir o caminho abaixo)
'''from google.colab import drive
drive.mount('/content/drive')

#após a autorização, copie o caminho do arquivo no seu drive (ache o arquivo e clique com o botão direito)
#dfBusiToronto = pd.read_csv('/content/drive/MyDrive/MineracaoDados/ConhecendoDados/businessToronto.csv')
'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')\n\n#após a autorização, copie o caminho do arquivo no seu drive (ache o arquivo e clique com o botão direito)\n#dfBusiToronto = pd.read_csv('/content/drive/MyDrive/MineracaoDados/ConhecendoDados/businessToronto.csv')\n"

# %% [markdown]
# ### Manipulações básicas

# %%
dfBusiToronto
# Out:
#                             _id             business_id  \
# 0      5f8a33caf961c6b3e3c5f018  zSpQmEBvRe3IhTUlMSA6HQ
# 1      5f8a33caf961c6b3e3c5f020  NDuUMJfrWk52RA-H-OtrpA
# 2      5f8a33caf961c6b3e3c5f024  C9keC4mWuXdl2mYFHZXudQ
# 3      5f8a33caf961c6b3e3c5f027  SP_YXIEwkFPPl_9anCYmpQ
# 4      5f8a33caf961c6b3e3c5f02f  C9oCPomVP0mtKa8z99E3gg
# ...                         ...                     ...
# 18901  5f8a33cff961c6b3e3c8e031  5XwfpotCAvDzPyAulk_m5A
# 18902  5f8a33cff961c6b3e3c8e03d  _mo-QIcmJgUwcjeunAwtew
# 18903  5f8a33cff961c6b3e3c8e04f  lo8WwqKogC-kz4toRvkdUQ
# 18904  5f8a33cff961c6b3e3c8e057  oS0CnUbyv0GUoD3L8_3UPQ
# 18905  5f8a33cff961c6b3e3c8e058  12yF9Vz4vH5DXcSeiUt6zw
#
#                          name                                        address  \
# 0          Totum Life Science                   445 King Street W, Suite 101
# 1              Bolt Fresh Bar                            1170 Queen Street W
# ...

# %%
dfBusiToronto.tail()
# Out:
#                             _id             business_id  \
# 18901  5f8a33cff961c6b3e3c8e031  5XwfpotCAvDzPyAulk_m5A
# 18902  5f8a33cff961c6b3e3c8e03d  _mo-QIcmJgUwcjeunAwtew
# 18903  5f8a33cff961c6b3e3c8e04f  lo8WwqKogC-kz4toRvkdUQ
# 18904  5f8a33cff961c6b3e3c8e057  oS0CnUbyv0GUoD3L8_3UPQ
# 18905  5f8a33cff961c6b3e3c8e058  12yF9Vz4vH5DXcSeiUt6zw
#
#                          name                                        address  \
# 18901               Starbucks                                1 Adelaide St E
# 18902  Espinosa Master Tailor  221 Davenport Rd  Toronto, ON M5R IJ3, Unit 9
# 18903         KOKO! Share Bar                            81 Yorkville Avenue
# 18904            Thai Fantasy                               578 Yonge Street
# 18905               LTS Nails                          540 Eglinton Avenue W
#
#           city state postal_code   latitude  longitude  stars  review_count  \
# 18901  Toronto    ON     M5C 2V9  43.650161 -79.377797    3.5             6
# ...

# %%
dfBusiToronto['name']
# Out:
# 0            Totum Life Science
# 1                Bolt Fresh Bar
# 2           Uncle Otis Clothing
# 3         The Steady Cafe & Bar
# 4                 Bakery Gateau
#                   ...
# 18901                 Starbucks
# 18902    Espinosa Master Tailor
# 18903           KOKO! Share Bar
# 18904              Thai Fantasy
# 18905                 LTS Nails
# Name: name, Length: 18906, dtype: object

# %%
dfBusiToronto.loc[:,'name']
# Out:
# 0            Totum Life Science
# 1                Bolt Fresh Bar
# 2           Uncle Otis Clothing
# 3         The Steady Cafe & Bar
# 4                 Bakery Gateau
#                   ...
# 18901                 Starbucks
# 18902    Espinosa Master Tailor
# 18903           KOKO! Share Bar
# 18904              Thai Fantasy
# 18905                 LTS Nails
# Name: name, Length: 18906, dtype: object

# %%
# Mostra a estrutura do dataframe (linhas, colunas)
dfBusiToronto.shape
# Out:
# (18906, 16)

# %%
# Remover a última coluna do dataframe - nome: "loc"
dfBusiToronto = dfBusiToronto.drop(['loc'], axis=1)
dfBusiToronto
# Out:
#                             _id             business_id  \
# 0      5f8a33caf961c6b3e3c5f018  zSpQmEBvRe3IhTUlMSA6HQ
# 1      5f8a33caf961c6b3e3c5f020  NDuUMJfrWk52RA-H-OtrpA
# 2      5f8a33caf961c6b3e3c5f024  C9keC4mWuXdl2mYFHZXudQ
# 3      5f8a33caf961c6b3e3c5f027  SP_YXIEwkFPPl_9anCYmpQ
# 4      5f8a33caf961c6b3e3c5f02f  C9oCPomVP0mtKa8z99E3gg
# ...                         ...                     ...
# 18901  5f8a33cff961c6b3e3c8e031  5XwfpotCAvDzPyAulk_m5A
# 18902  5f8a33cff961c6b3e3c8e03d  _mo-QIcmJgUwcjeunAwtew
# 18903  5f8a33cff961c6b3e3c8e04f  lo8WwqKogC-kz4toRvkdUQ
# 18904  5f8a33cff961c6b3e3c8e057  oS0CnUbyv0GUoD3L8_3UPQ
# 18905  5f8a33cff961c6b3e3c8e058  12yF9Vz4vH5DXcSeiUt6zw
#
#                          name                                        address  \
# 0          Totum Life Science                   445 King Street W, Suite 101
# 1              Bolt Fresh Bar                            1170 Queen Street W
# ...

# %%
#Adicionar uma nova coluna

dfBusiToronto['teste'] = 0

dfBusiToronto
# Out:
#                             _id             business_id  \
# 0      5f8a33caf961c6b3e3c5f018  zSpQmEBvRe3IhTUlMSA6HQ
# 1      5f8a33caf961c6b3e3c5f020  NDuUMJfrWk52RA-H-OtrpA
# 2      5f8a33caf961c6b3e3c5f024  C9keC4mWuXdl2mYFHZXudQ
# 3      5f8a33caf961c6b3e3c5f027  SP_YXIEwkFPPl_9anCYmpQ
# 4      5f8a33caf961c6b3e3c5f02f  C9oCPomVP0mtKa8z99E3gg
# ...                         ...                     ...
# 18901  5f8a33cff961c6b3e3c8e031  5XwfpotCAvDzPyAulk_m5A
# 18902  5f8a33cff961c6b3e3c8e03d  _mo-QIcmJgUwcjeunAwtew
# 18903  5f8a33cff961c6b3e3c8e04f  lo8WwqKogC-kz4toRvkdUQ
# 18904  5f8a33cff961c6b3e3c8e057  oS0CnUbyv0GUoD3L8_3UPQ
# 18905  5f8a33cff961c6b3e3c8e058  12yF9Vz4vH5DXcSeiUt6zw
#
#                          name                                        address  \
# 0          Totum Life Science                   445 King Street W, Suite 101
# 1              Bolt Fresh Bar                            1170 Queen Street W
# ...

# %% [markdown]
# #### Apply + Lambda

# %%
#Apply aplica uma função ao longo de um eixo do DataFrame.

dfBusiToronto.loc[:,['stars', 'review_count']].apply(lambda x: x+10)
# Out:
#        stars  review_count
# 0       14.0            33
# 1       13.0            67
# 2       15.0            22
# 3       13.5            39
# 4       14.5            18
# ...      ...           ...
# 18901   13.5            16
# 18902   14.0            16
# 18903   13.5            57
# 18904   14.0           123
# 18905   14.5            22
#
# [18906 rows x 2 columns]

# %% [markdown]
# ### Filtro

# %%
corte = dfBusiToronto['review_count'] > 100

dfBusiToronto[corte]
# Out:
#                             _id             business_id  \
# 19     5f8a33caf961c6b3e3c5f0b5  c35qzLN6ItDpVIoj2uQW4Q
# 22     5f8a33caf961c6b3e3c5f0c2  i6hWP3si97eKQl_JyK8L3w
# 50     5f8a33caf961c6b3e3c5f218  h_ypoQ2rmwX8UGSmohsGiQ
# 54     5f8a33caf961c6b3e3c5f24b  j_pi7HWSARbfKabuPRsXbw
# 72     5f8a33caf961c6b3e3c5f2d5  eoG9zP7xxsDHVM0kJYrvkw
# ...                         ...                     ...
# 18792  5f8a33cff961c6b3e3c8dbbc  kYD9E14AijONhJ7rFsyLrg
# 18822  5f8a33cff961c6b3e3c8dd45  An-JJle53UMHokU4MwFktg
# 18850  5f8a33cff961c6b3e3c8de85  B01pO_pI_8AOfEsukGNg-Q
# 18854  5f8a33cff961c6b3e3c8de96  _81fRJ9m8Fn1s8ixPun46A
# 18904  5f8a33cff961c6b3e3c8e057  oS0CnUbyv0GUoD3L8_3UPQ
#
#                             name  \
# 19                    Ravi Soups
# 22                Hilton Toronto
# 50                         Maman
# 54     The Ten Spot - Queen West
# 72        The Shameful Tiki Room
# ...                          ...
# 18792    The Elm Tree Restaurant
# ...

# %%
#Adicionando um novo atributio com base em um filtro

dfBusiToronto['popular'] = dfBusiToronto['review_count'] > 300

dfBusiToronto
# Out:
#                             _id             business_id  \
# 0      5f8a33caf961c6b3e3c5f018  zSpQmEBvRe3IhTUlMSA6HQ
# 1      5f8a33caf961c6b3e3c5f020  NDuUMJfrWk52RA-H-OtrpA
# 2      5f8a33caf961c6b3e3c5f024  C9keC4mWuXdl2mYFHZXudQ
# 3      5f8a33caf961c6b3e3c5f027  SP_YXIEwkFPPl_9anCYmpQ
# 4      5f8a33caf961c6b3e3c5f02f  C9oCPomVP0mtKa8z99E3gg
# ...                         ...                     ...
# 18901  5f8a33cff961c6b3e3c8e031  5XwfpotCAvDzPyAulk_m5A
# 18902  5f8a33cff961c6b3e3c8e03d  _mo-QIcmJgUwcjeunAwtew
# 18903  5f8a33cff961c6b3e3c8e04f  lo8WwqKogC-kz4toRvkdUQ
# 18904  5f8a33cff961c6b3e3c8e057  oS0CnUbyv0GUoD3L8_3UPQ
# 18905  5f8a33cff961c6b3e3c8e058  12yF9Vz4vH5DXcSeiUt6zw
#
#                          name                                        address  \
# 0          Totum Life Science                   445 King Street W, Suite 101
# 1              Bolt Fresh Bar                            1170 Queen Street W
# ...
